# %%
import copy

# %%
with open('lit_research.tex', 'r') as cc:
    content = cc.readlines()
    
content = [x.strip() for x in content] 

keywords = []
for ii in range(len(content)):
    if content[ii].find('printlist') != -1:
        keywords.append(content[ii][11:-1])
        
keywords.sort()
keywords.sort(key=len, reverse=True)

head_ = '\usepackage{luacode,luatexbase}\n\\newcommand{\kiteref}{\\noexpand\hyperref}\n\n%% Lua-side code\n\\begin{luacode}\nfunction ktrf ( buff )\n'
foot_ = 'return buff\nend\n\\end{luacode}\n\n%% TeX-side code\n\\newcommand\ktrfOn{\directlua{luatexbase.add_to_callback ( "process_input_buffer" , ktrf , "ktrf" )}}\n\\newcommand\ktrfOff{\directlua{luatexbase.remove_from_callback ( "process_input_buffer" , "ktrf" )}}\n\AtBeginDocument{\ktrfOn} % turn Lua function on by default'
 
with open('keylist.sty','wb') as f:
    f.write( head_ )

    for kk_ in keywords:
        f.write('\tbuff = string.gsub ( buff, "' + kk_.lower() + '", "\\\kiteref[' + kk_ + ']{' + kk_ + '}" )\n')
  
    f.write( foot_ )

# %%
keywords
# Out:
# ['Area 7a',
#  'Amygdala',
#  'Saccades',
#  'Striatum',
#  'Thalamus',
#  'Subiculum',
#  'Face motion',
#  'Premotor F5',
#  'Prosaccades',
#  'Antisaccades',
#  'Eye movement',
#  'Face patches',
#  'Priority map',
#  'Basal ganglia',
#  'Limbic system',
#  'Motor control',
#  'Reward system',
#  'Temporal lobe',
#  'Gaze following',
#  'Mirror neurons',
#  'Smooth pursuit',
#  'Theory of mind',
#  'Ventral stream',
#  'Visual streams',
#  'Body perception',
#  'Caudate nucleus',
#  'Face perception',
#  'Parietal Cortex',
#  'Visual saliency',
#  'Color perception',
#  'Long-term memory',
#  'Periphery effect',
#  'Reference frames',
#  'Social cognition',
#  'Visual attention',
#  'Domain Generality',
#  'Entorhinal cortex',
#  'Facial expression',
#  'Frontal eye field',
#  'Perirhinal cortex',
#  'Prefrontal Cortex',
#  'Social Perception',
#  'Spatial attention',
#  'Vestibular system',
#  'Domain specificity',
#  'Fusiform face area',
#  'Object recognition',
#  'Parietal eye field',
#  'Reflexive saccades',
#  'Social interaction',
#  'Superior colliculus',
#  'Default mode network',
#  'Face selective cells',
#  'Gaze control network',
#  'Gaze following patch',
#  'Head direction cells',
#  'Intentional saccades',
#  'Intraparietal sulcus',
#  'Predicitive saccades',
#  'Retrosplenial cortex',
#  'Face Inversion Effect',
#  'Temporal pole regions',
#  'Extrastriate body area',
#  'Medial temporal sulcus',
#  'Memory guided saccades',
#  'Supplementary eye field',
#  'Visual orienting system',
#  'Dorsal tegmental nucleus',
#  'Inferior temporal cortex',
#  'Medial Prefrontal Cortex',
#  'Superior Temporal Sulcus',
#  'Visual orientation model',
#  'Visually guided saccades',
#  'Anterior cingulate cortex',
#  'Attention control network',
#  'Posterior Parietal Cortex',
#  'Lateral intraparietal area',
#  'Lateral mammillary nucleus',
#  'Parahippocampal place area',
#  'Social interaction network',
#  'Dorsolateral Prefrontal Cortex',
#  'Ventrolateral Prefrontal Cortex']

# %%
content_ = copy.deepcopy(content)

with open('./sections/neuroN.tex', 'r') as f:
    content = f.readlines()
    
content = [x.strip() for x in content] 

inserted_ = 0
for ii in range(len(content)):
    cntr = 0
    if content[ii].find('begin{kite}') != -1:
        to_ = content[ii]
        if content[ii][12:].find('}') == -1:
            cntr = 1
            to_ = to_ + ' ' + content[ii+cntr]
            while content[ii+cntr].find('}') == -1:
                cntr = cntr+1
                to_ = to_ + ' ' + content[ii+cntr]

    if content[ii].find('end{kite}') != -1:
        content_.insert(ii+inserted_, '\par\kiteKey{' + to_[13:-1].lower() + '}' )   
        inserted_ = inserted_ + 1
        
with open('./sections/neuroNPY.tex', 'w') as fw:
    for item in content_:
        fw.write("%s\n" % item)

# %%
content_
# Out:
# ['\\begin{kite}{Face selective cells, Inferior temporal cortex, Superior temporal sulcus, Amygdala, Prefrontal Cortex}',
#  'face selective cells are in: IT, STS, Amygdala, PFC',
#  '\\par\\kiteKey{face selective cells, inferior temporal cortex, superior temporal sulcus, amygdala, prefrontal cortex}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Later intraparietal area, Priority map, Spatial attention}',
#  'LIP probably contains a priority map reflecting spatial attention',
#  '\\par\\kiteKey{later intraparietal area, priority map, spatial attention}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Inferior temporal cortex, Face perception}',
#  'Representation in Inferior temporal cortex shows relative tolerance',
#  'to the position of the face within the receptive field and the size',
#  'of the face itself',
#  '\\par\\kiteKey{inferior temporal cortex, face perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face patches, Face perception}',
#  'STS involved in extracting directional information',
#  '\\par\\kiteKey{superior temporal sulcus, face patches, face perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Priority map, Spatial attention,',
#  'Reference frames}',
#  'In IPS there are probably neurons that represent a priority map of',
#  'objects in visual space in a retina-centered reference frame.',
#  '\\par\\kiteKey{intraparietal sulcus, priority map, spatial attention, reference frames}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Later intraparietal area}',
#  'IPS in humans probably corresponds to LIP in monkey',
#  '\\par\\kiteKey{intraparietal sulcus, later intraparietal area}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Frontal eye field, Superior',
#  'colliculus, Saccades}',
#  'IPS, FEF and the superior colliculus are required to perform',
#  'saccades',
#  '\\par\\kiteKey{intraparietal sulcus, frontal eye field, superior colliculus, saccades}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Gaze following patch, Social Perception}',
#  'coding of changeable aspects of faces',
#  '\\par\\kiteKey{superior temporal sulcus, gaze following patch, social perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Parahippocampal place area, Fusiform face area, Object',
#  'perception}',
#  'Object based attention in PPA and FFA (?)',
#  '\\par\\kiteKey{parahippocampal place area, fusiform face area, object perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Extrastriate body area, Body perception}',
#  'EBA is involved in body perception and body parts',
#  '\\par\\kiteKey{extrastriate body area, body perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Parahippocampal place area, Limbic system, Long-term',
#  'memory, Object perception}',
#  'PPA is the posterior part of the parahippocampal gyrus which is',
#  'involved in memory and (object) recognition and part of the limbic',
#  'system',
#  '\\par\\kiteKey{parahippocampal place area, limbic system, long-term memory, object perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Periphery effect, Object recognition, Ventral stream, Fusiform face area, Parahippocampal place area}',
#  'periphery effect means that class specific areas in the temporal',
#  'lobe/ventral stream lose there specificity if objects are presented',
#  'in the periphery (Functional analysis of the periphery effect in',
#  'human building related areas., Levy 2004)',
#  '\\par\\kiteKey{periphery effect, object recognition, ventral stream, fusiform face area, parahippocampal place area}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Gaze following}',
#  'gaze following is largely a bottom-up process but are affected by',
#  'top-down information \\cite{Wiese2013,Teufel2009,Teufel2010}',
#  'This means that our overt attention is affected by bottom-up',
#  'processes but also by top-down modulation.',
#  '\\par\\kiteKey{gaze following}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Gaze following, Social Perception}',
#  'IPS region was shown to be active during gaze perception and gaze following, probably due to automatic or voluntary attentional shifts',
#  '\\cite{Hoffman2000,Pelphrey2003,Nummenmaa2010,Materna2008a,Laube2011,Marquardt2017}',
#  '\\par\\kiteKey{intraparietal sulcus, gaze following, social perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Gaze following, Medial temporal sulcus, Social cognition}',
#  '``The area Hamid identified is in the middle of the social system,',
#  "it gets probably input from MTS (motion)''",
#  '\\par\\kiteKey{superior temporal sulcus, gaze following, medial temporal sulcus, social cognition}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Social Perception}',
#  'There appears to be a left perceptual bias when judging emotional',
#  'state, identity and gender of faces. The left perceptual bias for',
#  'adult and infant faces in adults and 5-year-old children Face age',
#  'matters, Proietti, et al, 2014',
#  '\\par\\kiteKey{face perception, social perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Prefrontal cortex, Social cognition, Social Perception,',
#  'Parietal Cortex, Temporal cortex, Object recognition, Body',
#  'perception, Face perception, Face patches, Social interaction, Gaze',
#  'following, Theory of mind}',
#  'A network centered in the medial and ventrolateral prefrontal cortex',
#  'that is exclusively engaged in social interaction analysis. Two',
#  'additional networks, a parieto-premotor and a temporal one,',
#  'exhibited both social and physical interaction preference, which, in',
#  'the temporal lobe, mapped onto a fine-grain pattern of object, body,',
#  'and face selectivity. \\cite{Sliwa2017}',
#  '\\par\\kiteKey{prefrontal cortex, social cognition, social perception, parietal cortex, temporal cortex, object recognition, body perception, face perception, face patches, social interaction, gaze following, theory of mind}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Social interaction, Prefrontal cortex, Superior temporal sulcus,',
#  'Body perception, Face perception, Face patches, Social Perception}',
#  'Videos of inactive, active, and interacting monkeys all engaged',
#  'classical face and body areas in the superior temporal sulcus (STS)',
#  'and prefrontal cortex \\cite{Sliwa2017}',
#  '\\par\\kiteKey{social interaction, prefrontal cortex, superior temporal sulcus, body perception, face perception, face patches, social perception}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face-motion area middle dorsal, Face motion, Gaze',
#  'following, Superior temporal sulcus, Gaze following patch}',
#  'face-motion area middle dorsal (MD). Area specific for face motion',
#  'detection in the upper STS bank. \\cite{Fisher2015}',
#  '\\par\\kiteKey{face-motion area middle dorsal, face motion, gaze following, superior temporal sulcus, gaze following patch}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Lateral intraparietal area,',
#  'Social interaction, Social Perception, Premotor F5}',
#  'Area Anterior intraparietal area (posterior portion) of IPS and',
#  'premotor area F5 is engaged by physical and social interaction',
#  'perception. Both areas were activated by agent-object interactions',
#  '(Fig. 2E) but also by object-object interaction, and even more',
#  'strongly by social interaction. Social and physical in- teraction',
#  'representations overlapped in F5 but occupied neighboring locations',
#  'within pAIP \\cite{Sliwa2017}',
#  '\\par\\kiteKey{intraparietal sulcus, lateral intraparietal area, social interaction, social perception, premotor f5}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Social cognition, Medial Prefrontal Cortex, Anterior',
#  'cingulate cortex, Area 7a, Ventrolateral Prefrontal Cortex,',
#  'Temporal pole regions, Perirhinal cortex, Superior temporal',
#  'sulcus, Caudate nucleus, Amygdala, Social interaction network,',
#  'Social interaction}',
#  'social interaction network (SIN) included parts of the medial',
#  'prefrontal cortex (mPFC) and anterior cingulate cortex (ACC) (areas',
#  '32 and 10mr, and24b, respectively),dorsomedial prefrontal cortex',
#  '(dmPFC)(areasF6orPre-SMA,8Bm,and 9m), a temporo-parietal cluster',
#  '(areas TPOc and 7a), parts of the ventrolateral prefrontal cortex',
#  '(vlPFC) (ventral part of F5, ventral part of 44, the posterior part',
#  'of 47 and 12, and OPro), temporal pole regions (TPOi, STS areas 1',
#  'and 2, and TPpro), the perirhinal cortex (36R),dorsal STS areas[so-',
#  'cial posterior dorsal (sPD) and social anterior dorsal (sAD),',
#  'located dorsally to posterior lateral (PL) and anterior fundus (AF)',
#  'face patches, and anterior dorsal (AD), a face patch located',
#  'dorsally to face patch AF], and cortical and subcortical systems',
#  'engaged in reward, valence, and emotional processing [caudate;',
#  'amygdala; and areas 10o, 11l, and 14r of the orbitofrontal cortex',
#  '(OFC)] \\cite{Sliwa2017}',
#  '\\par\\kiteKey{social cognition, medial prefrontal cortex, anterior cingulate cortex, area 7a, ventrolateral prefrontal cortex, temporal pole regions, perirhinal cortex, superior temporal sulcus, caudate nucleus, amygdala, social interaction network, social interaction}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Default mode network, Theory of mind, Social cognition}',
#  'However, the joint characteristic of the ESIN\xe2\x80\x94 social cognition',
#  'focus and general deactivation during visual stimulation\xe2\x80\x94bear',
#  'resemblance to the human theory of mind (ToM) and the human',
#  'defaultmode network (DMN). ToM and DMN intersect in the human brain',
#  'at regions of quite plausible homology to ESIN areas of the macaque',
#  'brain. \\cite{Sliwa2017}',
#  '\\par\\kiteKey{default mode network, theory of mind, social cognition}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Theory of mind, Mirror neuron system, Gaze following}',
#  'Ithas been proposed that theMNSmight provide inputs to the ToM',
#  'network in humans \\cite{Blakemore2001}',
#  '\\par\\kiteKey{theory of mind, mirror neuron system, gaze following}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Mirror neurons, Gaze',
#  'following}',
#  'Neurons in LIP show mirror behavior: They fire when subject looks in',
#  'preferred direction and when observing monkeys looking at the',
#  'preferred direction. \\cite{Shepherd2009}',
#  '\\par\\kiteKey{lateral intraparietal area, mirror neurons, gaze following}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Theory of mind, Gaze following, Gaze following patch}',
#  'The ability to follow gaze is believed to be an important foundation',
#  'for theory of mind \\cite{Shepherd2009}',
#  '\\par\\kiteKey{theory of mind, gaze following, gaze following patch}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Amygdala, Visual orienting',
#  'system, Posterior Parietal Cortex, Lateral intraparietal area,',
#  'Area 7a}',
#  'Signals from STS and Amygdala ramify to multiple targets in the',
#  'visual orienting system (posterior parietal cortex, 7a, LIP)',
#  '\\cite{Shepherd2009}',
#  '\\par\\kiteKey{superior temporal sulcus, amygdala, visual orienting system, posterior parietal cortex, lateral intraparietal area, area 7a}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face perception,',
#  'Visual orienting system, Parietal Cortex}',
#  'Faces with averted gaze activate populations within the STS,',
#  'Amygdala and parietal cortex',
#  '\\cite{Shepherd2009}. This means that orientation is encoded',
#  '\\par\\kiteKey{superior temporal sulcus, face perception, visual orienting system, parietal cortex}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following, Superior temporal sulcus, Attention',
#  'control network, Gaze control network}',
#  'Hypothesis: gaze following is mediated by a simple system beginning',
#  'with STS and proceeding directly to the attention and gaze control',
#  'networks. \\par',
#  'Problem: gaze following fits poorly into attention models',
#  'dichotomizing attention into either exogenously driven or',
#  'endogenously driven. Second gaze following is very fast (100ms)',
#  '(Problem of using fMRI for identification of the relevant',
#  'areas). \\cite{Shepherd2009}',
#  '\\par\\kiteKey{gaze following, superior temporal sulcus, attention control network, gaze control network}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Visual orientation model, Gaze following, Visual',
#  'orienting system, Attention control network, Visual attention,',
#  'Lateral intraparietal area}',
#  'Random walk like model for visual orientation. Associate orienting',
#  'decision and neural activity within brain areas associated with',
#  'visual attention (e.g. LIP) \\cite{Shepherd2009}',
#  '\\par\\kiteKey{visual orientation model, gaze following, visual orienting system, attention control network, visual attention, lateral intraparietal area}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Visual attention, Lateral intraparietal area, Visual',
#  'saliency}',
#  'LIP activity has been linked to both overt and covert shift of',
#  'attention. Neuronal activity therein reflects visual saliency,',
#  'saccade likelihood and target value',
#  '\\par\\kiteKey{visual attention, lateral intraparietal area, visual saliency}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following}',
#  'gaze following magnitude and time course depends on dominance',
#  'status.',
#  '\\par\\kiteKey{gaze following}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Gaze following, Superior',
#  'temporal sulcus}',
#  'Thus, area LIP appears to spontaneously receive information about',
#  'where other individuals are looking, despite the fact that monkeys',
#  'were not trained to discriminate these cues or associate them with',
#  'rewards, and despite the fact that face cues did not predict the',
#  'location of saccade targets and, thus, were irrelevant to the',
#  'task. (hopefully from STS:))\\par',
#  'But are these neurons also modulated by other, non-social,',
#  'directional cues? \\par',
#  'Distinction between social gaze cue direction arises last',
#  '(100-200ms) compared to distinction between social gaze cues and',
#  'gray square stimuli (60-100ms) and image invariant stimulus onset',
#  '(50ms). This implies that LIP receives input from the successively',
#  'higher levels of the visual system with directional information',
#  'being high in the hierarchy.  \\cite{Shepherd2009}',
#  '\\par\\kiteKey{lateral intraparietal area, gaze following, superior temporal sulcus}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Saccades}',
#  'LIP population activity is negatively correlated with saccade',
#  'latency within a window of',
#  '148ms prior and 115ms after cue offset/target inset',
#  '\\cite{Shepherd2009}',
#  '\\par\\kiteKey{lateral intraparietal area, saccades}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Gaze following}',
#  'LIP neurons sensitive to gaze cues towards their receptive fields',
#  'most strongly responded to gaze cues towards their RF at latencies',
#  '100-500ms after cue onset. These neurons differentiate between gaze',
#  'cues towards and away from the RF in the period between 250-400 ms',
#  'after cue inset. This time course corresponds to gaze following',
#  'behavior time courses. The time course of those neurons whose',
#  'activity is diminished due to gaze cues is different from those who',
#  'are activated. \\cite{Shepherd2009}',
#  '\\par\\kiteKey{lateral intraparietal area, gaze following}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Social cognition, Reward',
#  'system, Visual saliency}',
#  'LIP may mediate social salience and oculomotor reward',
#  'contingencies. Gaze cue enhanced neurons signal the increased value',
#  'of acquiring information about regions of space where other monkeys',
#  'look at.',
#  '\\par\\kiteKey{lateral intraparietal area, social cognition, reward system, visual saliency}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Face motion, Superior temporal sulcus, Face patches, Face',
#  'perception}',
#  'Some areas in STS respond more to dynamic faces that to static',
#  'faces. (from paper club, 11.8.17)',
#  '\\par\\kiteKey{face motion, superior temporal sulcus, face patches, face perception}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Visual streams}',
#  'Freiwald proposed that there is dorsal and ventral stream within the',
#  'STS one for identity and one for dynamic features. (Hamid from paper',
#  'club, 11.8.17)',
#  '\\par\\kiteKey{superior temporal sulcus, visual streams}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face patches}',
#  'There is right hemispheric dominance in the face perception system',
#  '(Hamid from paper club, 11.8.17)',
#  '\\par\\kiteKey{face perception, face patches}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Face selective cells}',
#  'Switching the contrast of face stimuli lead to reduced response of',
#  'some face cells.',
#  '(Hamid from paper club, 11.8.17)',
#  '\\par\\kiteKey{face perception, face patches, face selective cells}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Head direction cells, Subiculum, Retrosplenial cortex,',
#  'Entorhinal cortex, Thalamus, Lateral mammillary nucleus, Dorsal',
#  'tegmental nucleus, Striatum, Face perception, Gaze following,',
#  'Visual orienting system, Vestibular system}',
#  'There are HD cells that have preferred head orientation, i.e. fire',
#  'when head is oriented accordingly. Can be found in postsubiculum',
#  '(also known as the dorsal presubiculum), retrosplenial cortex, and',
#  'entorhinal cortex, and subcortical regions including the thalamus',
#  '(the anterior dorsal and the lateral dorsal thalamic nuclei),',
#  'lateral mammillary nucleus,[12] dorsal tegmental nucleus and',
#  'striatum. It is thought that the cortical head direction cells',
#  'process information about the environment, while the subcortical',
#  'ones process information about angular head movements. In most areas',
#  'they are independent of the environment and landmarks, i.e. they',
#  'code head centered orientation. They depend on the vestibular',
#  'system.',
#  '\\par\\kiteKey{head direction cells, subiculum, retrosplenial cortex, entorhinal cortex, thalamus, lateral mammillary nucleus, dorsal tegmental nucleus, striatum, face perception, gaze following, visual orienting system, vestibular system}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Area 7a, Parietal Cortex}',
#  'Part of Brodmann area 7 that spans both the medial and lateral walls',
#  'of the parietal cortex. 7a lies on the cortical surface, between the',
#  'IPS and the STS, just dorsal (external) to LIP.  Medially, the area',
#  'corresponding to Brodmann area 7 is called precuneus. Laterally, it',
#  'is called the superior parietal lobule (SPL). At the base of the SPL',
#  'is the intraparietal sulcus, below which is the inferior parietal',
#  'lobule (IPL), which in turn divides into Brodmann areas 39 (angular',
#  'gyrus) and 40 (supramarginal gyrus) (from Wiki)',
#  '\\par\\kiteKey{area 7a, parietal cortex}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face selective cells, Face patches, Face recognition}',
#  'Face selective cells were discovered early',
#  '\\cite{Gross2002}, called Grandmother cells at that time',
#  '(cf. Lettvin).',
#  '\\par\\kiteKey{face selective cells, face patches, face recognition}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face patches, Face perception}',
#  'First discription of face patches by Kanwisher \\cite{Kanwisher1997}',
#  'and McCarthy \\cite{McCarthy1997}',
#  '\\par\\kiteKey{face patches, face perception}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception}',
#  'Face processing appears to be modular and distributed and it',
#  'proceeds in parallel and hierachical \\cite{Freiwald2016}',
#  '\\par\\kiteKey{face perception}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face perception, Face selective',
#  'cells, Face patches, Domain specificity, Prefrontal Cortex}',
#  'face selective cells have been found',
#  'across temporal and prefrontal cortex. At the same time there is',
#  'local clustering of these cells -- the face patches which are',
#  'primarily located in the lower bank of the STS and',
#  'mediodorsally in the fundus. The patches constitute a',
#  'domain specific specialized hardware. \\cite{Freiwald2016}',
#  '\\par\\kiteKey{superior temporal sulcus, face perception, face selective cells, face patches, domain specificity, prefrontal cortex}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Face, Visual streams,',
#  'Superior temporal sulcus}',
#  '\\kitebf{Posterior-anterior hierarchical organization of face',
#  'patches}\\par',
#  'Timing of activation of face patches shows that face areas are',
#  'hierachical organized along posterior-anterior axis -- response',
#  'latencies increase in this direction. Early, view-specific',
#  'representation is transformed to late, abstract and identity',
#  'specific representation. Also, hemispheric dominance exists in the',
#  'early patches like PL (posterior lateral face patch). In MF (middle',
#  'fundus) and ML (middle later) hemispheric dominance vanishes,',
#  'though, still view selective. View selectivity vanishes in AL',
#  '(anterior lateral face patch) and further in AM (anterior',
#  'medial).\\par',
#  '',
#  '\\kitebf{Ventro-dorsal organization}\\par',
#  'face patches in the fundus of the STS are the dorsal ones and more',
#  'for \\kitebf{face motion}, the ones in the lower bank (ventral) lack',
#  'this interest (This is true for human and NHP). This suggests',
#  'separated processing of different information in the visual',
#  'streams. \\par',
#  '',
#  'The reason why the face patches are that distributed may be that',
#  'they their location is governed by another organizational principle,',
#  'that is they belong to larger-scale processing-maps (cf. object',
#  'recognition, foveal bias etc.). \\cite{Freiwald2016}',
#  '\\par\\kiteKey{face perception, face patches, face, visual streams, superior temporal sulcus}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Body perception, Color',
#  'perception}',
#  'Ventral areas specialized for face perception (ventral face patches',
#  'PL, ML, AL, AM) are adjacent to body-selective areas (body',
#  'perception) and color-selective areas (color',
#  'perception). \\cite{Freiwald2016}',
#  '\\par\\kiteKey{face perception, face patches, body perception, color perception}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception}',
#  'Humans use contrast pairs e.g. forehead brighter than left eye to',
#  'detect faces. after \\cite{Freiwald2016} Cells exhibit consistent',
#  'preferences for a specific polarity of these pairs.',
#  '\\par\\kiteKey{face perception}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face, patches, Face Inversion Effect, Development of',
#  'the face processing system, Domain Generality, Domain',
#  'specificity, Face selective cells, Thatcher Illusion}',
#  'Key characteristic of human face recognition is the \\kitebf{holistic',
#  'nature} of upright-face processing relative to the more part-based',
#  'nature of object processing and inverted face',
#  'processing. This relates to the question of the',
#  'difference between the development of the face processing system and',
#  'whether it is innate or part of the domain general object',
#  'recognition instances. \\kiteit{The holistic nature suggests a',
#  'substantial difference to other object recognition',
#  'mechanisms}. The face-inversion effect is that humans perceive',
#  'face information far less precisely in inverted faces. \\par',
#  '',
#  'The face-inversion effect is much weaker for face selective cells',
#  'outside of the face patches.  \\cite{Freiwald2016}\\par',
#  '',
#  'Cells in MF and ML for example were tuned to more features in the',
#  'upright than in the inverted face. E.g. tuning to eyebrows was lost',
#  'entirely while tuning to mouth was generated de novo under inverted',
#  'condition. \\kitebf{this might be explained by a holistic face',
#  'template} \\par',
#  '',
#  "\\kiteit{Comment:} How does Tsao's face recognition hypothesis match",
#  'with this finding? How do the features deal with inverted faces?',
#  '\\kiteit{Should her coding hypothesis be invariant to inverted',
#  'faces?}\\par',
#  '',
#  'The finding that facial features a better recognized when viewed in',
#  'the facial context than when viewed in isolation likewise speaks for',
#  'a holistic processing principle of faces \\par',
#  '',
#  'Also mind the \\kitebf{thatcher illusion}: inversion of local',
#  'features -- those are hardly recognized in the inverted',
#  'face\\par',
#  '',
#  '\\kiteKey{domain generality, face inversion effect}',
#  '\\par\\kiteKey{face perception, face, patches, face inversion effect, development of the face processing system, domain generality, domain specificity, face selective cells, thatcher illusion}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following, Visual streams}',
#  'gaze following / direction of social attention is probably coded in',
#  'the dorsal stream of the face perception pathway. Also in the',
#  'ventral stream of the face perception pathway head-view selectivity',
#  'was found \\cite{Freiwald2016}',
#  '\\par\\kiteKey{gaze following, visual streams}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Prosopagnosia, Ventral occipital',
#  'lobe, Anterior temporal lobe}',
#  'prosopagnosia results form lesions extending from ventral occipital',
#  'lobe to anterior temporal lobe in the \\kitebf{right',
#  'hemisphere}. Unilateral left hemispheric lesion produce',
#  'prosopagnosia only rarely. \\kitebf{Strong right lateralization of',
#  'face processing in humans} \\cite{Freiwald2016} This was also',
#  'confirmed by stimulation studies.',
#  '\\par\\kiteKey{face perception, prosopagnosia, ventral occipital lobe, anterior temporal lobe}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Faces patches, Face perception,',
#  'Face motion, Facial expressions}',
#  'Patient R-ST1 with lesions restricted to the STS exhibited deficits',
#  'with facial expressions, consistent with the role of the STS face',
#  'patches in the processing of changeable aspects of faces. Especially',
#  'R-ST1 had problems with identity recognition if expression was not',
#  'constant. \\cite{Freiwald2016}\\par',
#  '',
#  '\\kiteKey{superior temporal sulcus, face patches, face perception,',
#  'face motion, facial expressions}',
#  '\\par\\kiteKey{superior temporal sulcus, faces patches, face perception, face motion, facial expressions}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Mental rotation, Motor cortex, Population code, Movement',
#  'vector, Direction selective neurons}',
#  'KEY: mental rotation, motor cortex, population code, movement',
#  'vector, direction selective neurons \\par',
#  '',
#  'Neurons in motor cortex code the direction of a movement as a',
#  'movement vector that is the weighted sum of direction selective',
#  'neurons. \\cite{Georgopoulos1989}\\par',
#  '',
#  '\\kiteit{Whats with rotations of 180 deg? is the mental rotation then',
#  'arbitrariliy clock- or counter-clock-wise? Since these are motor',
#  'neurons, does the rotation of the population vector mirrors in',
#  'behavior -- there should be an initial error in movement',
#  'direction?-- movement starts later, though. -- rotation part is',
#  'imaginary.}',
#  '\\par\\kiteKey{mental rotation, motor cortex, population code, movement vector, direction selective neurons}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Striatum, Basal ganglia}',
#  'Striatum is input structure of the basal ganglia',
#  '\\par\\kiteKey{striatum, basal ganglia}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Associative learning, Basal ganglia, Striatum, Prefrontal',
#  'Cortex}',
#  'Hypothesis that rewarded associations are first identified by the',
#  'basal ganglia, the output of which \xe2\x80\x98trains\xe2\x80\x99 slower learning',
#  'mechanisms in the frontal cortex.\\par',
#  '',
#  'Based on the first hypothesis, the PFC is predicted to lead the',
#  'basal ganglia; based on the second hypothesis, the basal ganglia',
#  'lead the PFC. Here, we report evidence in favour of the latter',
#  'event; that is, learning-related changes appear sooner and progress',
#  'more rapidly in the striatum than the PFC. \\cite{Pasupathy2005}',
#  '\\par\\kiteKey{associative learning, basal ganglia, striatum, prefrontal cortex}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Basal ganglia, Motor control, Volitional movements}',
#  'the basal ganglia are a group of subcortical nuclei long associated',
#  'with the control of volitional movements. \\cite{Pasupathy2005}',
#  '\\par\\kiteKey{basal ganglia, motor control, volitional movements}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Saccades, Lateral intraparietal area, Intraparietal',
#  'sulcus, Posterior parietal',
#  'cortex}',
#  'Different saccade types (evoked by microstimulation) are coded in',
#  'the posterior parietal cortex. Especially lateral intraparietal area',
#  'and intraparietal sulcus. Those are \\kitebf{modified vector',
#  'saccades} (amplitude modified my the position of the eyes at',
#  'saccade onset) and \\kitebf{goal directed saccades} (driving the eyes',
#  'to a certain region relative to the head (head centered goals))',
#  '\\cite{Anderson1998}',
#  '\\par\\kiteKey{saccades, lateral intraparietal area, intraparietal sulcus, posterior parietal cortex}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Frontal eye field, Pursuit eye movement}',
#  'FEF plays role in pursuit eye',
#  'movement. \\cite{Pierrot-Deseilligny2004}',
#  '\\par\\kiteKey{frontal eye field, pursuit eye movement}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Dorsolateral Prefrontal Cortex, Saccades, Decision',
#  'making}',
#  'dlPFC important for inhibition of unwanted reflexive saccades, dlPFC',
#  'governs decision processes also for oculomotor activity',
#  '\\cite{Pierrot-Deseilligny2004}\\par',
#  '',
#  '\\hfill\\kiteKey{[dorsolateral prefrontal cortex, saccades, decision',
#  'making]}',
#  '',
#  '\\par\\kiteKey{dorsolateral prefrontal cortex, saccades, decision making}',
#  '\\end{kite}']

# %%
content_.insert(-10, 'test')

# %%
content_
# Out:
# ['\\begin{kite}{Face selective cells, Inferior temporal cortex, Superior temporal sulcus, Amygdala, Prefrontal Cortex}',
#  'face selective cells are in: IT, STS, Amygdala, PFC',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Later intraparietal area, Priority map, Spatial attention}',
#  'LIP probably contains a priority map reflecting spatial attention',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Inferior temporal cortex, Face perception}',
#  'Representation in Inferior temporal cortex shows relative tolerance',
#  'to the position of the face within the receptive field and the size',
#  'of the face itself',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face patches, Face perception}',
#  'STS involved in extracting directional information',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Priority map, Spatial attention,',
#  'Reference frames}',
#  'In IPS there are probably neurons that represent a priority map of',
#  'objects in visual space in a retina-centered reference frame.',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Later intraparietal area}',
#  'IPS in humans probably corresponds to LIP in monkey',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Frontal eye field, Superior',
#  'colliculus, Saccades}',
#  'IPS, FEF and the superior colliculus are required to perform',
#  'saccades',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Gaze following patch, Social Perception}',
#  'coding of changeable aspects of faces',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Parahippocampal place area, Fusiform face area, Object',
#  'perception}',
#  'Object based attention in PPA and FFA (?)',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Extrastriate body area, Body perception}',
#  'EBA is involved in body perception and body parts',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Parahippocampal place area, Limbic system, Long-term',
#  'memory, Object perception}',
#  'PPA is the posterior part of the parahippocampal gyrus which is',
#  'involved in memory and (object) recognition and part of the limbic',
#  'system',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Periphery effect, Object recognition, Ventral stream, Fusiform face area, Parahippocampal place area}',
#  'periphery effect means that class specific areas in the temporal',
#  'lobe/ventral stream lose there specificity if objects are presented',
#  'in the periphery (Functional analysis of the periphery effect in',
#  'human building related areas., Levy 2004)',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Gaze following}',
#  'gaze following is largely a bottom-up process but are affected by',
#  'top-down information \\cite{Wiese2013,Teufel2009,Teufel2010}',
#  'This means that our overt attention is affected by bottom-up',
#  'processes but also by top-down modulation.',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Gaze following, Social Perception}',
#  'IPS region was shown to be active during gaze perception and gaze following, probably due to automatic or voluntary attentional shifts',
#  '\\cite{Hoffman2000,Pelphrey2003,Nummenmaa2010,Materna2008a,Laube2011,Marquardt2017}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Gaze following, Medial temporal sulcus, Social cognition}',
#  '``The area Hamid identified is in the middle of the social system,',
#  "it gets probably input from MTS (motion)''",
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Social Perception}',
#  'There appears to be a left perceptual bias when judging emotional',
#  'state, identity and gender of faces. The left perceptual bias for',
#  'adult and infant faces in adults and 5-year-old children Face age',
#  'matters, Proietti, et al, 2014',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Prefrontal cortex, Social cognition, Social Perception,',
#  'Parietal Cortex, Temporal cortex, Object recognition, Body',
#  'perception, Face perception, Face patches, Social interaction, Gaze',
#  'following, Theory of mind}',
#  'A network centered in the medial and ventrolateral prefrontal cortex',
#  'that is exclusively engaged in social interaction analysis. Two',
#  'additional networks, a parieto-premotor and a temporal one,',
#  'exhibited both social and physical interaction preference, which, in',
#  'the temporal lobe, mapped onto a fine-grain pattern of object, body,',
#  'and face selectivity. \\cite{Sliwa2017}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Social interaction, Prefrontal cortex, Superior temporal sulcus,',
#  'Body perception, Face perception, Face patches, Social Perception}',
#  'Videos of inactive, active, and interacting monkeys all engaged',
#  'classical face and body areas in the superior temporal sulcus (STS)',
#  'and prefrontal cortex \\cite{Sliwa2017}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face-motion area middle dorsal, Face motion, Gaze',
#  'following, Superior temporal sulcus, Gaze following patch}',
#  'face-motion area middle dorsal (MD). Area specific for face motion',
#  'detection in the upper STS bank. \\cite{Fisher2015}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Intraparietal sulcus, Lateral intraparietal area,',
#  'Social interaction, Social Perception, Premotor F5}',
#  'Area Anterior intraparietal area (posterior portion) of IPS and',
#  'premotor area F5 is engaged by physical and social interaction',
#  'perception. Both areas were activated by agent-object interactions',
#  '(Fig. 2E) but also by object-object interaction, and even more',
#  'strongly by social interaction. Social and physical in- teraction',
#  'representations overlapped in F5 but occupied neighboring locations',
#  'within pAIP \\cite{Sliwa2017}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Social cognition, Medial Prefrontal Cortex, Anterior',
#  'cingulate cortex, Area 7a, Ventrolateral Prefrontal Cortex,',
#  'Temporal pole regions, Perirhinal cortex, Superior temporal',
#  'sulcus, Caudate nucleus, Amygdala, Social interaction network,',
#  'Social interaction}',
#  'social interaction network (SIN) included parts of the medial',
#  'prefrontal cortex (mPFC) and anterior cingulate cortex (ACC) (areas',
#  '32 and 10mr, and24b, respectively),dorsomedial prefrontal cortex',
#  '(dmPFC)(areasF6orPre-SMA,8Bm,and 9m), a temporo-parietal cluster',
#  '(areas TPOc and 7a), parts of the ventrolateral prefrontal cortex',
#  '(vlPFC) (ventral part of F5, ventral part of 44, the posterior part',
#  'of 47 and 12, and OPro), temporal pole regions (TPOi, STS areas 1',
#  'and 2, and TPpro), the perirhinal cortex (36R),dorsal STS areas[so-',
#  'cial posterior dorsal (sPD) and social anterior dorsal (sAD),',
#  'located dorsally to posterior lateral (PL) and anterior fundus (AF)',
#  'face patches, and anterior dorsal (AD), a face patch located',
#  'dorsally to face patch AF], and cortical and subcortical systems',
#  'engaged in reward, valence, and emotional processing [caudate;',
#  'amygdala; and areas 10o, 11l, and 14r of the orbitofrontal cortex',
#  '(OFC)] \\cite{Sliwa2017}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Default mode network, Theory of mind, Social cognition}',
#  'However, the joint characteristic of the ESIN\xe2\x80\x94 social cognition',
#  'focus and general deactivation during visual stimulation\xe2\x80\x94bear',
#  'resemblance to the human theory of mind (ToM) and the human',
#  'defaultmode network (DMN). ToM and DMN intersect in the human brain',
#  'at regions of quite plausible homology to ESIN areas of the macaque',
#  'brain. \\cite{Sliwa2017}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Theory of mind, Mirror neuron system, Gaze following}',
#  'Ithas been proposed that theMNSmight provide inputs to the ToM',
#  'network in humans \\cite{Blakemore2001}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Mirror neurons, Gaze',
#  'following}',
#  'Neurons in LIP show mirror behavior: They fire when subject looks in',
#  'preferred direction and when observing monkeys looking at the',
#  'preferred direction. \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Theory of mind, Gaze following, Gaze following patch}',
#  'The ability to follow gaze is believed to be an important foundation',
#  'for theory of mind \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Amygdala, Visual orienting',
#  'system, Posterior Parietal Cortex, Lateral intraparietal area,',
#  'Area 7a}',
#  'Signals from STS and Amygdala ramify to multiple targets in the',
#  'visual orienting system (posterior parietal cortex, 7a, LIP)',
#  '\\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face perception,',
#  'Visual orienting system, Parietal Cortex}',
#  'Faces with averted gaze activate populations within the STS,',
#  'Amygdala and parietal cortex',
#  '\\cite{Shepherd2009}. This means that orientation is encoded',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following, Superior temporal sulcus, Attention',
#  'control network, Gaze control network}',
#  'Hypothesis: gaze following is mediated by a simple system beginning',
#  'with STS and proceeding directly to the attention and gaze control',
#  'networks. \\par',
#  'Problem: gaze following fits poorly into attention models',
#  'dichotomizing attention into either exogenously driven or',
#  'endogenously driven. Second gaze following is very fast (100ms)',
#  '(Problem of using fMRI for identification of the relevant',
#  'areas). \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Visual orientation model, Gaze following, Visual',
#  'orienting system, Attention control network, Visual attention,',
#  'Lateral intraparietal area}',
#  'Random walk like model for visual orientation. Associate orienting',
#  'decision and neural activity within brain areas associated with',
#  'visual attention (e.g. LIP) \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Visual attention, Lateral intraparietal area, Visual',
#  'saliency}',
#  'LIP activity has been linked to both overt and covert shift of',
#  'attention. Neuronal activity therein reflects visual saliency,',
#  'saccade likelihood and target value',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following}',
#  'gaze following magnitude and time course depends on dominance',
#  'status.',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Gaze following, Superior',
#  'temporal sulcus}',
#  'Thus, area LIP appears to spontaneously receive information about',
#  'where other individuals are looking, despite the fact that monkeys',
#  'were not trained to discriminate these cues or associate them with',
#  'rewards, and despite the fact that face cues did not predict the',
#  'location of saccade targets and, thus, were irrelevant to the',
#  'task. (hopefully from STS:))\\par',
#  'But are these neurons also modulated by other, non-social,',
#  'directional cues? \\par',
#  'Distinction between social gaze cue direction arises last',
#  '(100-200ms) compared to distinction between social gaze cues and',
#  'gray square stimuli (60-100ms) and image invariant stimulus onset',
#  '(50ms). This implies that LIP receives input from the successively',
#  'higher levels of the visual system with directional information',
#  'being high in the hierarchy.  \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Saccades}',
#  'LIP population activity is negatively correlated with saccade',
#  'latency within a window of',
#  '148ms prior and 115ms after cue offset/target inset',
#  '\\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Gaze following}',
#  'LIP neurons sensitive to gaze cues towards their receptive fields',
#  'most strongly responded to gaze cues towards their RF at latencies',
#  '100-500ms after cue onset. These neurons differentiate between gaze',
#  'cues towards and away from the RF in the period between 250-400 ms',
#  'after cue inset. This time course corresponds to gaze following',
#  'behavior time courses. The time course of those neurons whose',
#  'activity is diminished due to gaze cues is different from those who',
#  'are activated. \\cite{Shepherd2009}',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Lateral intraparietal area, Social cognition, Reward',
#  'system, Visual saliency}',
#  'LIP may mediate social salience and oculomotor reward',
#  'contingencies. Gaze cue enhanced neurons signal the increased value',
#  'of acquiring information about regions of space where other monkeys',
#  'look at.',
#  '\\end{kite}',
#  '',
#  '',
#  '',
#  '\\begin{kite}{Face motion, Superior temporal sulcus, Face patches, Face',
#  'perception}',
#  'Some areas in STS respond more to dynamic faces that to static',
#  'faces. (from paper club, 11.8.17)',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Visual streams}',
#  'Freiwald proposed that there is dorsal and ventral stream within the',
#  'STS one for identity and one for dynamic features. (Hamid from paper',
#  'club, 11.8.17)',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face patches}',
#  'There is right hemispheric dominance in the face perception system',
#  '(Hamid from paper club, 11.8.17)',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Face selective cells}',
#  'Switching the contrast of face stimuli lead to reduced response of',
#  'some face cells.',
#  '(Hamid from paper club, 11.8.17)',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Head direction cells, Subiculum, Retrosplenial cortex,',
#  'Entorhinal cortex, Thalamus, Lateral mammillary nucleus, Dorsal',
#  'tegmental nucleus, Striatum, Face perception, Gaze following,',
#  'Visual orienting system, Vestibular system}',
#  'There are HD cells that have preferred head orientation, i.e. fire',
#  'when head is oriented accordingly. Can be found in postsubiculum',
#  '(also known as the dorsal presubiculum), retrosplenial cortex, and',
#  'entorhinal cortex, and subcortical regions including the thalamus',
#  '(the anterior dorsal and the lateral dorsal thalamic nuclei),',
#  'lateral mammillary nucleus,[12] dorsal tegmental nucleus and',
#  'striatum. It is thought that the cortical head direction cells',
#  'process information about the environment, while the subcortical',
#  'ones process information about angular head movements. In most areas',
#  'they are independent of the environment and landmarks, i.e. they',
#  'code head centered orientation. They depend on the vestibular',
#  'system.',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Area 7a, Parietal Cortex}',
#  'Part of Brodmann area 7 that spans both the medial and lateral walls',
#  'of the parietal cortex. 7a lies on the cortical surface, between the',
#  'IPS and the STS, just dorsal (external) to LIP.  Medially, the area',
#  'corresponding to Brodmann area 7 is called precuneus. Laterally, it',
#  'is called the superior parietal lobule (SPL). At the base of the SPL',
#  'is the intraparietal sulcus, below which is the inferior parietal',
#  'lobule (IPL), which in turn divides into Brodmann areas 39 (angular',
#  'gyrus) and 40 (supramarginal gyrus) (from Wiki)',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face selective cells, Face patches, Face recognition}',
#  'Face selective cells were discovered early',
#  '\\cite{Gross2002}, called Grandmother cells at that time',
#  '(cf. Lettvin).',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face patches, Face perception}',
#  'First discription of face patches by Kanwisher \\cite{Kanwisher1997}',
#  'and McCarthy \\cite{McCarthy1997}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception}',
#  'Face processing appears to be modular and distributed and it',
#  'proceeds in parallel and hierachical \\cite{Freiwald2016}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Face perception, Face selective',
#  'cells, Face patches, Domain specificity, Prefrontal Cortex}',
#  'face selective cells have been found',
#  'across temporal and prefrontal cortex. At the same time there is',
#  'local clustering of these cells -- the face patches which are',
#  'primarily located in the lower bank of the STS and',
#  'mediodorsally in the fundus. The patches constitute a',
#  'domain specific specialized hardware. \\cite{Freiwald2016}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Face, Visual streams,',
#  'Superior temporal sulcus}',
#  '\\kitebf{Posterior-anterior hierarchical organization of face',
#  'patches}\\par',
#  'Timing of activation of face patches shows that face areas are',
#  'hierachical organized along posterior-anterior axis -- response',
#  'latencies increase in this direction. Early, view-specific',
#  'representation is transformed to late, abstract and identity',
#  'specific representation. Also, hemispheric dominance exists in the',
#  'early patches like PL (posterior lateral face patch). In MF (middle',
#  'fundus) and ML (middle later) hemispheric dominance vanishes,',
#  'though, still view selective. View selectivity vanishes in AL',
#  '(anterior lateral face patch) and further in AM (anterior',
#  'medial).\\par',
#  '',
#  '\\kitebf{Ventro-dorsal organization}\\par',
#  'face patches in the fundus of the STS are the dorsal ones and more',
#  'for \\kitebf{face motion}, the ones in the lower bank (ventral) lack',
#  'this interest (This is true for human and NHP). This suggests',
#  'separated processing of different information in the visual',
#  'streams. \\par',
#  '',
#  'The reason why the face patches are that distributed may be that',
#  'they their location is governed by another organizational principle,',
#  'that is they belong to larger-scale processing-maps (cf. object',
#  'recognition, foveal bias etc.). \\cite{Freiwald2016}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception, Face patches, Body perception, Color',
#  'perception}',
#  'Ventral areas specialized for face perception (ventral face patches',
#  'PL, ML, AL, AM) are adjacent to body-selective areas (body',
#  'perception) and color-selective areas (color',
#  'perception). \\cite{Freiwald2016}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Face perception}',
#  'Humans use contrast pairs e.g. forehead brighter than left eye to',
#  'detect faces. after \\cite{Freiwald2016} Cells exhibit consistent',
#  'preferences for a specific polarity of these pairs.',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Face, patches, Face Inversion Effect, Development of',
#  'the face processing system, Domain Generality, Domain',
#  'specificity, Face selective cells, Thatcher Illusion}',
#  'Key characteristic of human face recognition is the \\kitebf{holistic',
#  'nature} of upright-face processing relative to the more part-based',
#  'nature of object processing and inverted face',
#  'processing. This relates to the question of the',
#  'difference between the development of the face processing system and',
#  'whether it is innate or part of the domain general object',
#  'recognition instances. \\kiteit{The holistic nature suggests a',
#  'substantial difference to other object recognition',
#  'mechanisms}. The face-inversion effect is that humans perceive',
#  'face information far less precisely in inverted faces. \\par',
#  '',
#  'The face-inversion effect is much weaker for face selective cells',
#  'outside of the face patches.  \\cite{Freiwald2016}\\par',
#  '',
#  'Cells in MF and ML for example were tuned to more features in the',
#  'upright than in the inverted face. E.g. tuning to eyebrows was lost',
#  'entirely while tuning to mouth was generated de novo under inverted',
#  'condition. \\kitebf{this might be explained by a holistic face',
#  'template} \\par',
#  '',
#  "\\kiteit{Comment:} How does Tsao's face recognition hypothesis match",
#  'with this finding? How do the features deal with inverted faces?',
#  '\\kiteit{Should her coding hypothesis be invariant to inverted',
#  'faces?}\\par',
#  '',
#  'The finding that facial features a better recognized when viewed in',
#  'the facial context than when viewed in isolation likewise speaks for',
#  'a holistic processing principle of faces \\par',
#  '',
#  'Also mind the \\kitebf{thatcher illusion}: inversion of local',
#  'features -- those are hardly recognized in the inverted',
#  'face\\par',
#  '',
#  '\\kiteKey{domain generality, face inversion effect}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Gaze following, Visual streams}',
#  'gaze following / direction of social attention is probably coded in',
#  'the dorsal stream of the face perception pathway. Also in the',
#  'ventral stream of the face perception pathway head-view selectivity',
#  'was found \\cite{Freiwald2016}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Face perception, Prosopagnosia, Ventral occipital',
#  'lobe, Anterior temporal lobe}',
#  'prosopagnosia results form lesions extending from ventral occipital',
#  'lobe to anterior temporal lobe in the \\kitebf{right',
#  'hemisphere}. Unilateral left hemispheric lesion produce',
#  'prosopagnosia only rarely. \\kitebf{Strong right lateralization of',
#  'face processing in humans} \\cite{Freiwald2016} This was also',
#  'confirmed by stimulation studies.',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Superior temporal sulcus, Faces patches, Face perception,',
#  'Face motion, Facial expressions}',
#  'Patient R-ST1 with lesions restricted to the STS exhibited deficits',
#  'with facial expressions, consistent with the role of the STS face',
#  'patches in the processing of changeable aspects of faces. Especially',
#  'R-ST1 had problems with identity recognition if expression was not',
#  'constant. \\cite{Freiwald2016}\\par',
#  '',
#  '\\kiteKey{superior temporal sulcus, face patches, face perception,',
#  'face motion, facial expressions}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Mental rotation, Motor cortex, Population code, Movement',
#  'vector, Direction selective neurons}',
#  'KEY: mental rotation, motor cortex, population code, movement',
#  'vector, direction selective neurons \\par',
#  '',
#  'Neurons in motor cortex code the direction of a movement as a',
#  'movement vector that is the weighted sum of direction selective',
#  'neurons. \\cite{Georgopoulos1989}\\par',
#  '',
#  '\\kiteit{Whats with rotations of 180 deg? is the mental rotation then',
#  'arbitrariliy clock- or counter-clock-wise? Since these are motor',
#  'neurons, does the rotation of the population vector mirrors in',
#  'behavior -- there should be an initial error in movement',
#  'direction?-- movement starts later, though. -- rotation part is',
#  'imaginary.}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Striatum, Basal ganglia}',
#  'Striatum is input structure of the basal ganglia',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Associative learning, Basal ganglia, Striatum, Prefrontal',
#  'Cortex}',
#  'Hypothesis that rewarded associations are first identified by the',
#  'basal ganglia, the output of which \xe2\x80\x98trains\xe2\x80\x99 slower learning',
#  'mechanisms in the frontal cortex.\\par',
#  '',
#  'Based on the first hypothesis, the PFC is predicted to lead the',
#  'basal ganglia; based on the second hypothesis, the basal ganglia',
#  'lead the PFC. Here, we report evidence in favour of the latter',
#  'event; that is, learning-related changes appear sooner and progress',
#  'more rapidly in the striatum than the PFC. \\cite{Pasupathy2005}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Basal ganglia, Motor control, Volitional movements}',
#  'the basal ganglia are a group of subcortical nuclei long associated',
#  'with the control of volitional movements. \\cite{Pasupathy2005}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Saccades, Lateral intraparietal area, Intraparietal',
#  'sulcus, Posterior parietal',
#  'cortex}',
#  'Different saccade types (evoked by microstimulation) are coded in',
#  'the posterior parietal cortex. Especially lateral intraparietal area',
#  'and intraparietal sulcus. Those are \\kitebf{modified vector',
#  'saccades} (amplitude modified my the position of the eyes at',
#  'saccade onset) and \\kitebf{goal directed saccades} (driving the eyes',
#  'to a certain region relative to the head (head centered goals))',
#  '\\cite{Anderson1998}',
#  '\\end{kite}',
#  '',
#  '',
#  '\\begin{kite}{Frontal eye field, Pursuit eye movement}',
#  'FEF plays role in pursuit eye',
#  'movement. \\cite{Pierrot-Deseilligny2004}',
#  '\\end{kite}',
#  '',
#  '\\begin{kite}{Dorsolateral Prefrontal Cortex, Saccades, Decision',
#  'test',
#  'making}',
#  'dlPFC important for inhibition of unwanted reflexive saccades, dlPFC',
#  'governs decision processes also for oculomotor activity',
#  '\\cite{Pierrot-Deseilligny2004}\\par',
#  '',
#  '\\hfill\\kiteKey{[dorsolateral prefrontal cortex, saccades, decision',
#  'making]}',
#  '',
#  'test',
#  '\\end{kite}']

# %%
list(find_all(content[0], '}')) <= 11
# Out:
# False

# %%
3!>4
# Out:
#   File "<ipython-input-182-15017817c9f4>", line 1
#     3!>4
#      ^
# SyntaxError: invalid syntax
